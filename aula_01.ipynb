# %% [markdown]
# <a href="https://colab.research.google.com/github/marcostc/ImersaoDados_Alura/blob/main/aula_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Olá!
#
# Seja bem-vinda  ou bem-vindo ao notebook da aula 01, nesta aula vamos realizar nossa primeira análise de dados e no final já seremos capazes de tirar algumas conclusões.
#
# Nós desenvolveremos nosso projeto aqui no google colaboratory, assim podemos mesclar células contendo textos em formato markdown e células de código, além disso você não precisa instalar nada na sua máquina. Então, que tal começar testando algumas linhas de código?
#
# No campo abaixo temos o que chamamos de célula. Na célula nós podemos digitar textos, cálculos e códigos.
#
# Após eu introduzir o que eu quero na célula eu vou rodar esse conteúdo. Para isso podemos usar o atalho SHIFT + ENTER, ou até mesmo clicar no símbolo de play no canto esquerdo da célula. Na primeira vez que rodamos algo no nosso notebook ele vai demorar um pouco mais de tempo, e isso ocorre porque o google está alocando uma máquina virtual para nós utilizarmos.

# %% [markdown]
# # Importando os dados
#
# Nessa imersão nós vamos mergulhar no universo da biologia e da biotecnologia e explorar uma base de dados da área.
#
# Para a nossa análise, está faltando então os dados. Para conseguirmos esses dados vamos acessar o Github, nesse link:
#
# https://github.com/alura-cursos/imersaodados3/tree/main/dados
#
# Então, agora vamos importar essa base de dados para dentro do nosso notebook. Para juntar essas informações vamos utilizar nossa famosa biblioteca do "Pandas".
# Vamos importar essa biblioteca através do seguinte código:

# %%
import pandas as pd

url_dados = 'https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_experimentos.zip?raw=true'

dados = pd.read_csv(url_dados, compression = 'zip')
dados
# Out:
#                  id    tratamento  tempo dose  ...  c-96  c-97  c-98  c-99
# 0      id_000644bb2     com_droga     24   D1  ... -0.40  0.21  0.38  0.42
# 1      id_000779bfc     com_droga     72   D1  ...  0.15  0.12  0.61  0.74
# 2      id_000a6266a     com_droga     48   D1  ... -0.64 -0.22 -1.41  0.69
# 3      id_0015fd391     com_droga     48   D1  ... -1.62 -0.88 -0.39 -0.82
# 4      id_001626bd3     com_droga     72   D2  ...  0.11  0.29 -0.38  0.71
# ...             ...           ...    ...  ...  ...   ...   ...   ...   ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.06  0.92  0.53  0.47
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.21 -0.12 -0.27  0.37
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.23  0.76  0.67  0.38
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.17  0.70 -0.63  0.07
# 23813  id_ffffdd77b     com_droga     72   D1  ... -3.58 -0.48 -2.15 -4.25
#
# [23814 rows x 877 columns]

# %% [markdown]
# Observe que imprimimos agora todas as nossas linhas e colunas da nossa tabela.
#
# Aqui observamos que temos dados referentes a ID, tratamento, tempo, dose, entre outras.
#
# Para nos auxiliar na visualização e na identificação das colunas dos dados que vamos trabalhar, faremos um recorte, uma espécie de cabeçalho, com 5 linhas, e para isso usamos o seguinte comando:

# %%
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %% [markdown]
# Quando estávamos trabalhando com o conjunto total de dados nós tínhamos a informação do número total de linhas e colunas. Porém, agora com o head, nós perdemos essa informação. Então, caso você queira recuperar a informação do total de linhas e colunas basta utilizar:

# %%
dados.shape
# Out:
# (23814, 877)

# %% [markdown]
# Então, agora vamos voltar para o nosso problema.
#
# Nós queremos iniciar fazendo uma análise dos dados que estamos tratando. Vamos começar selecionando só uma coluna, para entendermos do que ela está tratando.
#
# Vamos iniciar com a coluna tratamento. Para isso vamos digitar:

# %%
dados['tratamento']
# Out:
# 0           com_droga
# 1           com_droga
# 2           com_droga
# 3           com_droga
# 4           com_droga
#              ...
# 23809       com_droga
# 23810       com_droga
# 23811    com_controle
# 23812       com_droga
# 23813       com_droga
# Name: tratamento, Length: 23814, dtype: object

# %% [markdown]
# Esse tipo de informação, da coluna, é o que chamamos de 'série'. Já a tabela inteira nós chamos de 'dataframe'.
#
# Agora para vermos os tipos específicos de informação que temos dentro dessa coluna vamos digitar:

# %%
dados['tratamento'].unique()
# Out:
# array(['com_droga', 'com_controle'], dtype=object)

# %% [markdown]
# A resposta foi dada no formato de array, que nada mais é do que um vetor, ou seja, um tipo de estrutura de dados.
#
# Observe que encontramos dois tipos: 'com droga' e 'com controle'.
#
# Com droga, como o próprio nome nos diz, é quando estamos aplicando algum tipo de droga para a amostra. Já com o controle é uma técnica estatística em que isolamos as outras varíaveis e observamos apenas a variável de interesse.

# %% [markdown]
# Agora vamos analisar a coluna do tempo:

# %%
dados['tempo'].unique()
# Out:
# array([24, 72, 48])

# %% [markdown]
# Encontramos 3 tipos de informação nessa coluna: 24, 72 e 48. O que pode nos indicar o tempo, provavelmente em horas, de intervalo que foi administrada a dose de medicamentos ou drogas.
#
# É interessante que observamos o comportamento das células com essa diferença de tempo, já que se analisássemos num período diferente poderia não dar tempo suficiente pra célula manifestar o determinado comportamento.

# %% [markdown]
# Além do tempo, podemos analisar também a coluna de dose:

# %%
dados['dose'].unique()
# Out:
# array(['D1', 'D2'], dtype=object)

# %% [markdown]
# Aqui obtemos dois tipos de doses diferentes, d1 e d2, mas não conseguimos afirmar nada categoricamente de antemão.

# %% [markdown]
# Vamos então analisar a categoria droga:

# %%
dados['droga'].unique()
# Out:
# array(['b68db1d53', 'df89a8e5a', '18bb41b2c', ..., '573c787a2',
#        'b2fe3eca7', 'dd4a96d16'], dtype=object)

# %% [markdown]
# Agora com a resposta de ```dados['droga'].unique()``` obtivemos essa série de códigos como resposta. Talvez esses números foram codificados na tentativa de anonimizar os tipos de drogas usadas, para tentar evitar qualquer tipo de viés na análise dos resultados.
#
# Há uma série de regras quando alguns experimentos são feitos, evitando mostrar dados como nome, sexo, e outros fatores, dependendo da análise a ser feita, para que sejam evitados vieses.

# %% [markdown]
# Vamos analisar a coluna nomeada como g-0 agora:

# %%
dados['g-0'].unique()
# Out:
# array([ 1.062 ,  0.0743,  0.628 , ...,  0.3942,  0.666 , -0.8598])

# %% [markdown]
# Só olhando fica difícil tentar deduzir o que esses números representam. Então, nesse ponto, com o auxílio da Vanessa, especialista, conseguimos a informação que essa letra 'g' da coluna remete à palavra gene. Ou seja, esses números nos dizem a expressão de cada gene frente as drogas ou a exposição.
#
# Quando subimos de volta na tabela, percebemos que há diversos valores, inclusive com várias casas decimais. Aparentemente esses números foram "arredondados", normalizados, para podermos compará-los de alguma forma.
#
# Então, até agora na nossa análise, já conseguimos identificar e entender as informações de diferentes colunas; as colunas que nos indicam os tratamentos, as drogas, o tempo, e depois as respostas genéticas, que tem a letra g no ínicio do seu nome.
#
# Outro tipo de análise que podemos fazer agora é entender a distribuição dessas informações. Por exemplo, podemos saber quantos experimentos temos utilizando droga e quantos não utilizam; quantos usam o d1, e quantos utilizam o d2, e assim por diante.
#
# Como podemos fazer isso? Vamos utilizar esse código:

# %%
dados['tratamento'].value_counts()
# Out:
# com_droga       21948
# com_controle     1866
# Name: tratamento, dtype: int64

# %% [markdown]
# Agora, em vez de usarmos o ```.unique``` no código, nós utilizamos o ```.value_counts``` já que nosso objetivo era contar a quantidade de valores que apareciam nas colunas, nesse caso, na coluna ```tratamento```.
#
# No resultado ele retornou 2 linhas: uma com a quantidade de elementos que temos, ou seja, com a minha frequência, na categoria ```com_droga``` e a outra com a quantidade que temos na categoria ```com_controle```.
#
# Houve uma grande diferença no resultado dessas categorias, não é mesmo? Isso é, no mínimo, curioso. Então, Guilherme vai nos sugerir um desafio, de investigar o por quê dessa diferença tão grande.
#
# Nesse momento o Thiago já escreve outros dois desafios, o desafio #2 e o desafio #3. E a Vanessa também deixa o seu, desafio #4. Todos os desafios dessa aula estão escritos no final desse notebook.

# %% [markdown]
# Será que essa diferença entre os valores dentro das categorias continuam tão desproporcionais? Vamos investigar a categoria ```dose```:

# %%
dados['dose'].value_counts()
# Out:
# D1    12147
# D2    11667
# Name: dose, dtype: int64

# %% [markdown]
# Nesse ponto parece que as coisas já estão mais equilibradas. Mas somente com o número é difícil fazermos uma leitura mais aprofundada. Então, nesse momento, vamos resolver um dos desafios deixados. Então, se até aqui você ainda nao resolveu os desafios do vídeo e nao quer receber um spoiler, pare aqui e tente resolvê-los primeiro.

# %% [markdown]
# Para entendermos melhor e fazer um comparativo é legal traçarmos a proporção entre os dados. Vamos escrever o código agora, setando como parâmetro, dentro dos parênteses o ```normalize = True``` :

# %%
dados['tratamento'].value_counts(normalize = True)
# Out:
# com_droga       0.921643
# com_controle    0.078357
# Name: tratamento, dtype: float64

# %% [markdown]
# Temos agora os dados "normalizados". Podemos interpretar utilizando a porcentagem (multiplicando por 100), o que nos daria algo em torno de 92% versus 8% (aproximadamente), mostrando o tamanho da desproporção.

# %% [markdown]
# Vamos fazer o mesmo agora com a coluna ```dose```:

# %%
dados['dose'].value_counts(normalize = True)
# Out:
# D1    0.510078
# D2    0.489922
# Name: dose, dtype: float64

# %% [markdown]
# Temos aqui o resultado. Inclusive, como mini-desafio, você pode fazer o mesmo processo com as outras colunas.
#
# Certo, mas geralmente, quando há a trasmissão dessas informações, vemos uma série de gráficos. E, geralmente, é usado aquele gráfico que parece uma torta, ou uma pizza.
#
# Vamos então plotar um gráfico dessa tipo, com o seguinte código:

# %%
dados['tratamento'].value_counts().plot.pie()

# %% [markdown]
# Aqui, em azul, nós temos a quantidade de tratamento com drogas(que é muito maior, em proporção), e em laranja temos o tratamento "com controle". Ficou até parecendo um pacman, hehe.
#
# Vamos aproveitar e analisar as outras informações com os gráficos também, para vermos o que acontece. Vamos analisar a coluna tempo:

# %%
dados['tempo'].value_counts().plot.pie()

# %% [markdown]
# Repare como ficou difícil a olho nú identificarmos qual observação é maior através do gráfico. Esse tipo de gráfico pode acabar dificultando um pouco a análise, especialmente quando as informações estão melhor balanceadas.
#
# Além de identificar a quantidade de horas observadas, nós não conseguimos extrair mais nenhuma informação desse gráfico. Inclusive, nós temos uma espécie de regrinha, que diz que quando formos fazer algum tipo de análise, procurarmos evitar o uso de gráficos que nos remetem a comida, como por exemplo: rosca, pizza, torta, e assim por diante.
#
# Então qual tipo de gráfico poderíamos utlizar para melhorarmos nossa visualização? Vamos utilizar o gráfico de barras, através deste código:

# %%
dados['tempo'].value_counts().plot.bar()

# %% [markdown]
# Agora sim conseguimos identificar com mais facilidade qual observação tem a sua maior frequência. Na verdade a quantidade de horas com o maior número de observações foi a de 48.
#
# No eixo y temos o número que nos remete ao número de observações. Então podemos observar que tivemos pouco mais de 8000 observações relativas às 48 horas.
#
# Então, o gráfico de barras acabou sendo muit mais útil, nesse caso, do que o gráfico de pizza.

# %% [markdown]
# Ao longo da aula nós falamos sobre a expressão gênica. Se nós voltarmos à tabela, na coluna g-0, nós temos alguns valores dentro de um intervalo definido. Para não termos valores muito distantes entre si, é bastante comum no meio científico que haja uma normalização dos resultados, para criamos um intervalo que não seja tão grande, em que o meio dessa distribuição seja o 0.
#
# Como nós podemos saber em quais linhas dessa coluna, o meu valor está acima de 0?
#
# Vamos fazer uma consulta nos nossos dados, da seguinte maneira:

# %%
dados_filtrados = dados[dados['g-0'] > 0]
dados_filtrados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 6  id_001bd861f  com_droga     24   D2  ...  2.4670  0.0357  0.1351 -0.3179
# 7  id_0020d0484  com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
#
# [5 rows x 877 columns]

# %% [markdown]
# Dessa maneira, temos somente as 5 primeiras linhas com o valores maiores do que 0 na coluna g-0, com a ajuda dessa máscara com o código ```[dados['g-0']>0]```.
#
# Dessa mesma forma que aplicamos essa máscara, podemos utilizar o mesmo caminho, ou outras 'querys', para responder várias outras perguntas.
#
# Assim, temos outro desafio, o #5, de procurar na documentação do pandas o método query.
#
# Além desse temos outros desafios, o #6 e o #7 e o #8, todos eles estão logo abaixo.

# %%
pd.set_option('display.max_columns', 500)
dados
# Out:
#                  id    tratamento  tempo dose      droga     g-0     g-1  \
# 0      id_000644bb2     com_droga     24   D1  b68db1d53  1.0620  0.5577
# 1      id_000779bfc     com_droga     72   D1  df89a8e5a  0.0743  0.4087
# 2      id_000a6266a     com_droga     48   D1  18bb41b2c  0.6280  0.5817
# 3      id_0015fd391     com_droga     48   D1  8c7f86626 -0.5138 -0.2491
# 4      id_001626bd3     com_droga     72   D2  7cbed3131 -0.3254 -0.4009
# ...             ...           ...    ...  ...        ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  df1d0a5a1  0.1394 -0.0636
# 23810  id_fffb70c0c     com_droga     24   D2  ecf3b6b74 -1.3260  0.3478
# 23811  id_fffc1c3f4  com_controle     48   D2  cacb2b860  0.3942  0.3756
# 23812  id_fffcb9e7c     com_droga     24   D1  8b87a7a83  0.6660  0.2324
# 23813  id_ffffdd77b     com_droga     72   D1  972f41291 -0.8598  1.0240
#
#           g-2     g-3     g-4     g-5     g-6     g-7     g-8     g-9    g-10  \
# 0     -0.2479 -0.6208 -0.1944 -1.0120 -1.0220 -0.0326  0.5548 -0.0921  1.1830
# 1      0.2991  0.0604  1.0190  0.5207  0.2341  0.3372 -0.4047  0.8507 -1.1520
# 2      1.5540 -0.0764 -0.0323  1.2390  0.1715  0.2155  0.0065  1.2300 -0.4797
# 3     -0.2656  0.5288  4.0620 -0.8095 -1.9590  0.1792 -0.1321 -1.0600 -0.8269
# 4      0.9700  0.6919  1.4180 -0.8244 -0.2800 -0.1498 -0.8789  0.8630 -0.2219
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 23809 -0.1112 -0.5080 -0.4713  0.7201  0.5773  0.3055 -0.4726  0.1269  0.2531
# 23810 -0.3743  0.9905 -0.7178  0.6621 -0.2252 -0.5565  0.5112  0.6727 -0.1851
# 23811  0.3109 -0.7389  0.5505 -0.0159 -0.2541  0.1745 -0.0340  0.4865 -0.1854
# 23812  0.4392  0.2044  0.8531 -0.0343  0.0323  0.0463  0.4299 -0.7985  0.5742
# 23813 -0.1361  0.7952 -0.3611 -3.6750 -1.2420  0.9146  3.0790  1.2460  1.9460
#
#          g-11    g-12    g-13    g-14    g-15    g-16    g-17    g-18    g-19  \
# 0      0.1530  0.5574 -0.4015  0.1789 -0.6528 -0.7969  0.6342  0.1778 -0.3694
# 1     -0.4201 -0.0958  0.4590  0.0803  0.2250  0.5293  0.2839 -0.3494  0.2883
# 2     -0.5631 -0.0366 -1.8300  0.6057 -0.3278  0.6042 -0.3075 -0.1147 -0.0570
# 3     -0.3584 -0.8511 -0.5844 -2.5690  0.8183 -0.0532 -0.8554  0.1160 -2.3520
# 4     -0.5121 -0.9577  1.1750  0.2042  0.1970  0.1244 -1.7090 -0.3543 -0.5160
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 23809  0.1730 -0.4532 -1.0790  0.2474 -0.4550  0.3588  0.1600 -0.7362 -0.1103
# 23810  2.8650 -0.2140 -0.6153  0.8362  0.5584 -0.2589  0.1292  0.0148  0.0949
# 23811  0.0716  0.1729 -0.0434  0.1542 -0.2192 -0.0302 -0.4218  0.4057 -0.5372
# 23812  0.1421  2.2700  0.2046  0.5363 -1.7330  0.1450  0.6097  0.2024  0.9865
# 23813  1.4370  2.9780  2.2370 -0.6818  0.6870 -1.1060  0.0182 -0.9247 -0.0738
#
#          g-20    g-21    g-22    g-23    g-24    g-25    g-26    g-27    g-28  \
# 0     -0.5688 -1.1360 -1.1880  0.6940  0.4393  0.2664  0.1907  0.1628 -0.2853
# 1      0.9449 -0.1646 -0.2657 -0.3372  0.3135 -0.4316  0.4773  0.2075 -0.4216
# 2     -0.0799 -0.8181 -1.5320  0.2307  0.4901  0.4780 -1.3970  4.6240 -0.0437
# 3      2.1200 -1.1580 -0.7191 -0.8004 -1.4670 -0.0107 -0.8995  0.2406 -0.2479
# 4     -0.3330 -0.2685  0.7649  0.2057  1.3720  0.6835  0.8056 -0.3754 -1.2090
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 23809  0.8550 -0.4139  0.5541  0.2310 -0.5573 -0.4397 -0.9260 -0.2424 -0.6686
# 23810 -0.2182 -0.9235  0.0749 -1.5910 -0.8359 -0.9217  0.3013  0.1716  0.0880
# 23811  0.1521 -0.2651  0.2310 -0.8101  0.4943  0.6905 -0.3720 -1.4110  0.4516
# 23812 -0.7805  0.9608  0.3440  2.7650  0.4925  0.6698  0.2374 -0.3372  0.8771
# 23813 -0.1919 -0.7722 -1.4050 -1.0050 -1.1170 -0.5293 -1.1720 -0.2885  0.1599
#
#          g-29    g-30    g-31    g-32    g-33    g-34    g-35    g-36    g-37  \
# 0      0.5819  0.2934 -0.5584 -0.0916 -0.3010 -0.1537  0.2198  0.2965 -0.5055
# 1     -0.1161 -0.0499 -0.2627  0.9959 -0.2483  0.2655 -0.2102  0.1656  0.5300
# 2      1.2870 -1.8530  0.6069  0.4290  0.1783  0.0018 -1.1800  0.1256 -0.1219
# 3     -1.0890 -0.7575  0.0881 -2.7370  0.8745  0.5787 -1.6740 -1.6720 -1.2690
# 4      0.2965 -0.0712  0.6389  0.6674 -0.0783  1.1740 -0.7110 -1.4470  1.0620
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 23809  0.2326  0.6456  0.0136 -0.5141 -0.6320  0.7166 -0.1736  0.3686 -0.1565
# 23810  0.1842  0.1835  0.5436 -0.0533 -0.0491  0.9543  0.4626  0.0819  0.1586
# 23811  1.2300 -0.1949 -1.3280 -0.4276 -0.0040 -0.3086 -0.2355 -0.5222 -1.1470
# 23812 -2.6560 -0.2000 -0.2043  0.6797 -0.0248 -0.0927  1.8480 -2.7180 -5.3160
# 23813 -0.4250  0.3591 -0.1420 -0.9530 -0.2005 -1.8340 -0.5768  0.5145 -0.9913
#
#          g-38    g-39    g-40    g-41    g-42    g-43    g-44    g-45    g-46  \
# 0     -0.5119 -0.2162 -0.0347 -0.2566 -1.1980  0.3116 -1.0330  0.2208 -0.1143
# 1     -0.2568 -0.0455  0.1194 -0.3958 -1.1730  0.4509  1.9250  1.1010  0.2648
# 2      5.4470  1.0310  0.3477 -0.5561  0.0357 -0.3636 -0.4653 -0.8346  0.1113
# 3      3.0900 -0.3814 -0.7229 -0.0010  0.1353 -1.6400 -0.7483 -1.0820 -0.1521
# 4      0.7888 -0.0848  0.1302  0.1224  0.9584  0.2126  0.6162  1.1570  1.1140
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 23809 -0.7362  0.1318  0.1119  1.3410  0.0813 -0.2178 -1.1840  0.5063 -0.8763
# 23810  1.2050  0.0384 -0.0843 -0.8834 -0.6190  0.2070 -0.0265 -3.2790 -0.0587
# 23811  0.2844  0.0813 -0.4128 -0.2369  0.3507  0.2589 -0.2534 -0.1554 -1.3170
# 23812 -1.0750 -0.1437 -0.1714  0.0329  0.8309 -0.3018  0.1599  1.5520 -0.0280
# 23813  3.1350 -0.2644 -0.3885 -0.7888  0.3372  0.9194  0.3385 -0.4935 -0.1130
#
#          g-47    g-48    g-49    g-50    g-51    g-52    g-53    g-54    g-55  \
# 0     -0.0251  0.0350  0.4233 -0.1221 -0.4927  0.6119  0.4715 -0.0351 -0.1605
# 1     -0.3615  0.1710 -0.8900  1.2730 -0.5036 -0.2277 -0.7339 -0.4283 -0.1231
# 2     -0.7615 -0.4983  0.4552 -0.0978 -0.2661  0.6058  0.2686 -0.6191 -0.4444
# 3      0.0747 -0.4851  0.6636 -2.8230 -0.6035 -1.3550  2.0200 -0.5301 -1.3240
# 4     -0.9416 -0.3780 -0.8147 -0.0803 -0.3818  0.6877  0.0000  0.1776  1.1320
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 23809 -0.3036 -0.2647 -0.3275 -0.2505 -0.3948  1.1560  0.3564  1.7600  0.1839
# 23810  0.8523 -0.1349  0.4453 -0.4211 -0.3773 -0.2667  1.5350  1.2830 -0.3146
# 23811 -0.2351  0.9172  0.0146 -0.2557  0.7447 -0.0546  1.0260  0.9798  0.0692
# 23812  2.7900  2.8060  0.8933 -4.3160  0.4567 -1.6260  0.2735  0.0425  1.4880
# 23813 -1.3550 -1.0350  2.4320 -0.0852  0.3169  0.3251  0.6992  0.8032  1.1830
#
#          g-56    g-57    g-58    g-59    g-60    g-61    g-62    g-63    g-64  \
# 0     -0.6750  0.2263  0.5790  0.9588  0.6061 -0.1300  0.6611 -0.3136 -0.2020
# 1     -0.6328  0.4759  0.3249 -0.7408 -0.5814  1.7840 -0.1087  1.0350  0.4087
# 2      1.2540  0.0621 -0.1757 -1.4370  0.5553  0.8346 -0.3334 -0.2933 -0.1644
# 3     -0.5936  0.4331  0.0899 -1.5240  0.3936  1.4630 -1.2100 -1.2340 -1.0300
# 4     -0.1180  1.2130  0.7709  0.6745  0.7871  1.6410  0.1806  1.3480  1.1070
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 23809  0.6089 -1.0800 -0.2057 -0.3546 -0.0004 -0.2103 -0.4110 -0.1667 -0.2021
# 23810  0.4491  0.9932 -0.0196 -0.5625  0.4468 -0.8176 -1.0710 -0.0422 -0.4293
# 23811 -0.4405  0.8411  0.0359  0.1095 -0.0036  0.4868  0.8449  0.1728 -0.0723
# 23812 -0.1895 -0.4778 -6.2950 -3.2500 -1.6760  0.2570  2.5190 -1.9730  0.7292
# 23813  0.8404 -0.2576  0.5438  1.7080 -0.4274 -1.0110 -2.2130 -0.7770 -0.2826
#
#          g-65    g-66    g-67    g-68    g-69    g-70    g-71    g-72    g-73  \
# 0      0.0251  0.1670 -0.4195  0.6551 -0.7395 -0.7047 -0.5369  0.0314 -0.5239
# 1     -0.6948 -0.8026  0.0954 -0.4054  0.1197  0.1956  0.0720 -0.2463 -0.1084
# 2     -1.1280 -0.0292  0.0939  0.5916  0.6809  0.7821  0.6801  0.9634  0.4057
# 3      0.7977  0.2314  0.1186  1.5370  0.3868 -0.4038  0.9767 -0.9161  1.2720
# 4      0.5392  0.0000  0.1255 -0.1556 -0.5436  0.8585  0.5801  0.9348 -0.7508
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 23809 -0.8097  1.0590 -0.0928 -0.4539  1.5720  0.4938 -0.0538  2.8000 -1.1270
# 23810  1.7480 -0.3259 -0.5476  1.5890  0.5003 -0.5807 -0.0282  0.4695 -0.4573
# 23811 -0.9579  0.3553  0.2957  0.0860 -0.4175 -0.4059  0.0181  0.2744 -0.6236
# 23812  0.2777 -2.7170  0.1275 -0.5875 -0.0457 -0.5292 -1.0270 -4.1960 -1.6420
# 23813  2.6890 -0.6858 -2.7760  0.5267 -2.4060 -0.3186 -0.9862 -0.5422  0.2270
#
#          g-74    g-75    g-76    g-77    g-78    g-79    g-80    g-81    g-82  \
# 0     -0.3406 -0.6332 -1.0330 -0.3763 -0.8550  0.7348 -0.2226 -0.1959 -0.0005
# 1      0.4008 -0.5857  0.8933  0.2842  1.1870  0.7311  0.7734 -1.5920 -1.3500
# 2     -0.0708 -1.3570  0.2306 -0.4130 -0.1406  0.3078 -0.4273 -0.8073  1.0050
# 3      1.3670 -3.3210 -1.0510 -0.7074  1.0380 -0.7296 -0.9796  0.1337  0.3262
# 4     -1.1160 -0.7868  0.1675 -0.3088  0.6630 -1.7000  0.4253 -1.1700 -0.8736
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 23809 -0.1192  0.1710 -0.0022 -0.9539 -0.3808 -0.0582  1.1530 -0.3501  1.6200
# 23810 -0.0041  0.0452  0.2975  0.1427  0.3917  0.6482 -0.0952 -0.8375 -0.2503
# 23811 -1.3690  0.8459 -0.8486 -0.3350 -0.3531  0.6647  0.0245  0.1045  0.1828
# 23812  0.1236  3.3020 -1.1660  0.4877 -0.0095  0.3904  1.0310  0.3541  1.4340
# 23813  1.3940 -3.6610 -1.2730  1.3520 -1.6600  0.1873 -1.6680  0.0238  1.2610
#
#          g-83    g-84    g-85    g-86    g-87    g-88    g-89    g-90    g-91  \
# 0     -2.1440  1.7320  0.0190 -0.1188  0.4050 -1.5840 -0.3011  0.2048 -1.1230
# 1      0.0055 -0.6507 -0.3979  0.6976  0.1383  0.2558  0.2563  0.0563 -0.3854
# 2     -0.0678 -0.0617 -0.1562  0.4080  0.7163 -0.2040 -0.9246  0.8540  0.4286
# 3      0.5635  0.8961  1.0280  0.0508 -0.4742  1.1640  0.2764  1.6310  4.9160
# 4      0.6169 -1.2160 -0.1491 -2.2520  0.6823  1.4800  0.9068 -0.7982  0.8025
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 23809  1.8170  0.0539 -1.4720  1.0610  0.0000 -0.3185  0.0066  0.3191 -0.2432
# 23810 -0.3026  0.7048  0.9419 -1.1300 -0.1289 -0.2178 -0.6941 -0.1718 -0.5028
# 23811 -0.4841  0.1743  1.0680  0.6122  1.1980  1.0670 -0.5320  0.2070 -2.3820
# 23812  0.1981  1.4210  1.0250  0.6968 -0.8704 -1.4690  1.4010 -1.1450  0.6629
# 23813  1.8740 -0.6282  1.4340  1.3590 -1.1360 -0.8128  1.0420 -0.0500  2.5210
#
#          g-92    g-93    g-94    g-95    g-96    g-97    g-98    g-99   g-100  \
# 0     -1.5590 -1.7980  0.7017 -1.0390  0.0958  0.4527  0.5455 -0.0828 -0.5364
# 1     -0.6528 -0.1740 -0.0188 -0.4910 -1.3820  0.4300 -0.3965  0.1346  0.7129
# 2      0.3396  1.6870 -0.6283  0.2548  0.6822  0.0955 -0.3061  0.7335 -0.7646
# 3      2.3690  0.6832 -1.4810  1.4310  0.1686 -1.7220  0.0892 -0.8117  1.0390
# 4      1.2990  1.0690 -0.1518 -0.8001  1.1940 -0.2334  0.2345 -0.4384  0.0968
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 23809  0.1165  0.1577 -0.4658  0.0431 -0.0060 -1.2870 -0.2978  0.7565 -0.6344
# 23810 -0.6314 -0.0759 -0.5828 -0.6147 -0.6208  0.5167 -0.0555 -0.1017 -0.5803
# 23811  0.5315 -0.0493 -0.5473 -0.0640  0.4431 -0.8123  0.6885 -0.7116 -0.2501
# 23812 -0.0486  0.6615  1.0920  0.0594 -3.2490  1.3320  0.2780  0.2104  1.5780
# 23813  1.4930 -1.5740 -0.6398  1.4450  1.2540 -0.2394  2.7030 -0.4748 -1.7970
#
#         g-101   g-102   g-103   g-104   g-105   g-106   g-107   g-108   g-109  \
# 0      0.5522 -0.7768 -0.8044 -0.1181 -1.2560  0.1593 -0.6998 -1.7470  0.7120
# 1     -0.0724 -0.8599 -0.3863 -0.0948 -0.5932 -0.1630 -0.2356  0.2319  0.0487
# 2     -0.3154  0.6849  0.7327  0.0000 -0.4462 -0.9601 -0.2600 -0.7443  0.1388
# 3     -0.0851  2.0570 -0.7968  0.0000  1.6720 -0.1619 -0.9467 -0.4938 -0.2653
# 4     -1.1880 -1.3030  0.6187  0.0000  1.1790 -0.8521 -0.2801  0.4686 -0.5360
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 23809 -0.4885 -0.6021  0.8779  0.6745 -0.5609 -0.0340  2.5000 -1.3490 -0.2484
# 23810  0.0769  0.0736 -0.1192 -0.6310  0.3084  0.0604 -0.2564  0.5234  0.4939
# 23811  1.5140 -0.6676 -0.1340 -1.1490  0.9153 -1.0590 -0.6912  0.2254  0.8401
# 23812  2.1210  0.1758 -0.6600  0.0546  0.3485  1.1430  0.0552 -0.7127  0.7140
# 23813 -0.0360  0.8515  0.7813 -0.0728 -2.0830  1.4810 -0.1406 -0.4162 -0.4850
#
#         g-110   g-111   g-112   g-113   g-114   g-115   g-116   g-117   g-118  \
# 0     -0.7635 -0.0290  1.2670  0.4734 -0.9902  0.4391 -0.1188 -0.0348  0.4676
# 1      0.7302  0.0271 -0.1482  0.2702  0.8842 -0.2944 -0.4810  0.0268 -1.2140
# 2     -0.1204 -0.0079 -0.8991 -0.1627 -0.3827 -0.1245 -0.7449 -0.4446 -0.2475
# 3     -0.7025 -0.3582 -0.1362 -2.0530  0.2815 -0.0158 -0.5371 -1.8970  0.0636
# 4     -0.2246 -2.3510 -0.9180  0.3001  0.8598 -2.3350 -0.6522  0.0481 -1.6780
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 23809  0.1319 -0.5712  0.0593 -1.1270  1.4810  0.1473  0.7889 -0.8059 -0.5202
# 23810 -0.6777  1.4850  0.0266 -0.5037  1.0880  0.0883 -0.6697 -0.9882  0.5015
# 23811 -0.4148  0.0894  0.6156  0.2602  1.6250 -0.7255  0.0288 -0.1750 -0.4746
# 23812 -0.2484  0.0914  1.1740 -0.9923 -0.5238  0.4257  2.1290  1.6260  0.5778
# 23813  0.5925  1.7020  0.7337 -4.5490  0.9787  0.0309 -0.6520 -1.4890  0.9635
#
#         g-119   g-120   g-121   g-122   g-123   g-124   g-125   g-126   g-127  \
# 0      1.9750  0.0545  1.2880  1.2260  0.0486 -0.8622 -1.2770 -0.1810 -0.2600
# 1      1.7630  0.7860  0.0232  0.0152  0.0804 -0.8073  1.1340 -0.2540 -0.1643
# 2     -0.0184  0.2551 -0.9627  1.0660  0.1807  0.2413  0.9176 -0.0486 -0.3885
# 3      0.2328 -0.7206 -1.3960  0.6489 -0.2583  1.4160 -1.5420  0.4545  0.2297
# 4      1.1890 -3.8480  0.7353 -1.0690 -1.3950 -0.6294  1.1970 -1.3880  1.2030
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 23809 -0.4038  0.1609 -0.1772  0.5069 -0.8420  0.5888 -0.2478 -1.2480  0.4244
# 23810 -0.0226 -0.4309 -0.1508 -0.1681  0.0813  0.1632 -0.7472 -1.7980 -0.4611
# 23811 -0.1562 -0.4193  0.2435 -1.0070  0.2131 -0.1851  0.2930 -0.1969  0.1493
# 23812  0.2813  1.8140 -3.7630  0.3056  0.3399  0.9847 -0.1256  0.3404 -0.1487
# 23813 -0.5908 -0.2284  0.0128  0.7936  0.7676  1.2920 -5.3450  1.1080 -1.9970
#
#         g-128   g-129   g-130   g-131   g-132   g-133   g-134   g-135   g-136  \
# 0     -0.5130 -0.0227 -0.2257 -0.7349  0.3116 -0.8774  0.3539  0.2833 -0.3501
# 1     -0.6529  1.1480  0.2172 -0.0493  0.0806 -0.8065 -0.3062 -0.4078  0.5039
# 2     -0.2843  0.3051 -0.1750 -0.3465 -0.6194 -0.6888  0.6535 -0.0302 -0.0747
# 3      0.8581  0.2128  0.0973  3.0850  0.0196 -0.3923 -1.2910  0.2836 -0.5197
# 4      0.6597  0.6237  1.5330  2.0390  0.4533 -1.4210 -0.1871 -1.7040  0.9155
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 23809  0.1275 -0.0691 -0.4165 -0.0885  0.2141 -0.8223  1.5420 -0.4658  0.4966
# 23810  0.7780 -0.7149  0.5081  0.2747  0.1231 -0.5979  0.0046  0.0190 -0.3726
# 23811  0.9588 -0.9413  0.4748 -0.6812 -0.2074  0.7802 -0.3971  0.0000 -1.3880
# 23812 -0.5318  0.0062  0.4944  0.9327 -0.3004  1.7600 -2.2900  0.9528 -1.7730
# 23813  2.0390  2.4060 -1.2130  2.5280  0.0587 -0.9221 -2.3510 -0.4438 -0.5927
#
#         g-137   g-138   g-139   g-140   g-141   g-142   g-143   g-144   g-145  \
# 0     -0.4372 -0.4646 -0.4940  0.5297  1.2420 -1.1870  0.4382  1.1360 -0.1758
# 1      0.7468 -0.0415  0.9550 -0.4778 -1.3910  0.1903 -0.4695 -0.5351 -0.3524
# 2     -0.0095 -0.4059 -0.7744 -1.1260 -0.8119  0.3927  1.8060 -0.0104  2.4450
# 3     -0.0278  1.0140  1.1300 -0.3831 -0.2767  0.5993 -0.5146  0.4468  1.7270
# 4      0.3770  0.9127  0.5022  0.0851 -2.4280 -0.8599 -0.3822 -1.7530 -0.4152
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 23809 -0.7921  0.7012  0.1521 -0.7646  0.0345  0.2021 -0.6213  0.0496  0.0019
# 23810 -1.3280  0.3732 -0.4630  0.1674  0.1267  0.0370 -0.0970  1.6250  0.4637
# 23811  2.6940  1.5560 -0.3229 -0.0675  0.1306 -0.5124 -0.2987 -0.7658  0.4390
# 23812  0.5729  0.9409 -0.1002  2.0600 -0.0040 -0.4342  0.9864  0.7340  0.3332
# 23813  0.1070 -1.0680 -0.8700  1.6150  3.0420 -0.7440  0.4326  2.6450  0.3196
#
#         g-146   g-147   g-148   g-149   g-150   g-151   g-152   g-153   g-154  \
# 0      0.3858 -1.2530 -0.1779  0.5655 -0.1696  0.1464 -0.1973 -0.4959  0.2655
# 1     -0.9459  0.0287  0.5038 -0.4026  0.2609  0.1743  0.5582  0.5020 -0.6926
# 2     -0.1512  0.6194  1.7050 -1.8500 -0.8219 -0.2035 -0.6910  0.5166  0.1713
# 3      1.1450  0.8178  4.2300 -1.7170 -0.3004 -0.2569 -3.0280 -0.2357 -0.2941
# 4     -0.5948 -0.2815  0.4478  0.0795  1.8640 -1.3230  0.7051 -1.9440 -0.5804
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 23809  0.1122 -0.1310  0.5324 -1.0470 -0.0179  0.6983  0.2500  0.5861 -0.2621
# 23810 -0.1065  0.0939  0.2327  0.3350  0.4937 -0.5440 -3.4390 -0.3504  1.7710
# 23811 -0.1592 -0.4418 -0.3251 -0.1165 -0.6418 -0.0420 -0.3167  0.7675  0.5185
# 23812  4.1350 -0.7608 -0.4645  2.5790  0.0502  1.2080 -3.8680 -0.2363  0.9762
# 23813 -0.3358 -0.2762 -1.5920 -1.7830 -0.2312  0.7933 -2.2680 -0.5680  1.3030
#
#         g-155   g-156   g-157   g-158   g-159   g-160   g-161   g-162   g-163  \
# 0      0.4279 -0.0202 -0.1091 -0.7799 -0.8062 -0.3239  0.2411 -1.0170 -0.5592
# 1     -0.0407  1.0120  0.1305  0.1049 -0.1423  0.0882  1.1880 -0.5056 -0.0163
# 2     -0.2872 -1.4870  0.3598  0.3011  0.4400  1.7920 -4.1810  2.1840 -0.9974
# 3     -1.0680 -1.6470  0.5287  4.2110 -0.5516  0.8118 -0.8374  1.0510  1.1430
# 4     -2.4960  0.4042  0.0000  0.9283  1.4940 -0.8757 -0.3667  0.4272 -0.9715
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 23809 -0.0687  0.0000 -0.6917 -0.0268  0.4381 -1.1670  0.2147 -0.0811 -0.5493
# 23810 -0.3171 -0.0952  0.2738  1.1030  0.8671 -0.5854  0.2914  0.3517  0.4096
# 23811 -0.5870  0.6769  0.6816 -0.6342  0.2118  0.9198 -0.7033 -0.5068 -0.4354
# 23812  0.7601 -1.0480 -0.2283  2.7990 -0.8270 -0.1616 -0.0892  0.2215 -0.0530
# 23813  1.7830 -3.6190 -7.3100  1.4420 -1.9280 -0.2432 -0.1978 -0.6509  1.9200
#
#         g-164   g-165   g-166   g-167   g-168   g-169   g-170   g-171   g-172  \
# 0     -0.4386  0.0590  0.3816  0.0817 -0.8457  0.5989 -0.4194  0.0858  0.7449
# 1     -1.4020  0.6522  1.2160 -0.0478  0.3713  0.2215  0.2610  0.3841 -0.1476
# 2      0.2307 -0.8124  0.8455 -2.7010 -0.9168 -1.1480  0.0825 -0.6908 -0.4245
# 3      0.9099 -0.2411 -1.3680  1.0670  0.2782  1.4610 -0.5527 -1.0070 -0.0910
# 4      0.3501  0.3622 -0.8955  0.1902  1.1520  0.6745  0.6135 -1.4480 -0.6243
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 23809 -0.3679  0.2254  0.3715  0.7272 -0.7530 -0.5404 -0.3922 -0.6072  0.4957
# 23810  0.1683  0.1694 -0.2905  0.0876 -0.4057 -0.6637  1.9000  0.1474 -0.0008
# 23811  0.3191  0.4308 -0.0847 -0.0088  0.0623  0.7284 -1.0460 -0.2621  0.3743
# 23812 -1.1780  0.4536  0.3412  0.1616 -1.3600  2.9900 -0.5219  1.2750  1.3240
# 23813  2.0810  0.0046 -0.9451 -0.1914  0.1608  0.3920  0.6606 -0.3013 -1.5410
#
#         g-173   g-174   g-175   g-176   g-177   g-178   g-179   g-180   g-181  \
# 0      1.6820 -0.2471 -1.4130 -0.2031 -0.2256 -0.6217  0.4969  0.1109 -0.3284
# 1     -1.2850 -0.6565  0.2697  0.0919  0.2341  1.3360 -0.1854  0.0325  0.1416
# 2     -0.3494 -0.1320  1.1870 -2.6240 -1.6640  0.1667 -1.2800  0.7258 -0.3007
# 3     -1.0610  0.7465  3.4580 -0.5228  0.3133 -3.1620 -1.2130  0.0650  1.6530
# 4     -1.6000 -0.0913  0.5282  1.6050  0.5905 -0.8969 -0.9344 -0.9038 -0.5732
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 23809 -0.7224 -2.2190 -0.0242 -0.3336 -0.1702 -0.0384 -0.1616  1.3700 -0.0483
# 23810 -0.4054 -0.0484  0.1418 -1.5170  0.4364  0.3836 -0.4096 -0.0336  0.1441
# 23811  0.5535  0.0318 -0.3812  0.5561  0.4815  0.1023 -0.0243  1.1890  0.1587
# 23812  1.2070  0.4711  1.1370  1.9500 -0.6053  0.2138  0.1516  0.6375  0.2301
# 23813 -0.1477  0.2364  0.9669 -0.0473  0.9685 -7.7590  0.9988  0.2819  0.1538
#
#         g-182   g-183   g-184   g-185   g-186   g-187   g-188   g-189   g-190  \
# 0      0.2469 -0.2786  0.2318 -0.5274  0.5698 -0.2100  1.4050 -0.1078  0.1064
# 1     -0.2420 -0.2166 -0.5338  0.1229 -0.2280 -0.3149  0.7871 -0.1145 -0.2067
# 2      0.5677  0.4284 -0.2485 -2.1940 -0.0611  0.0544  3.6780 -0.9055  2.0350
# 3     -0.0022  0.0864  0.8989 -0.8746 -1.4210 -0.2400 -0.1266 -2.5660  3.5620
# 4     -0.6177  0.1723 -0.6239 -0.8446 -0.8357  0.6745  0.5846 -0.0990  0.8706
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 23809  0.9888 -1.4850 -0.0546 -0.3764  0.1975 -1.2830  0.3572 -0.0372  1.0480
# 23810  1.0220 -0.7146  1.3050 -0.2896  0.1535  0.1387 -0.5915  0.4984 -0.4785
# 23811 -0.1467  0.5487 -0.5811  0.6396 -0.4577  0.9821  0.1533 -0.1305  0.5227
# 23812  0.0444 -0.7397 -1.3610 -3.5700 -2.3680  1.2300  2.3480  1.8680  0.8115
# 23813 -0.0076  0.2962  0.6016 -0.9603 -1.6340  0.4118 -2.5200  0.7783 -0.5804
#
#         g-191   g-192   g-193   g-194   g-195   g-196   g-197   g-198   g-199  \
# 0     -0.2164  0.0917  0.4796 -0.1509  0.7374 -0.7406 -0.5210 -0.0491  0.8366
# 1     -0.3810  0.3166 -1.4640 -0.1521  0.4040  0.6048  0.1126 -0.2919 -0.3401
# 2      1.1970 -0.3382  0.4036  1.1240 -0.0200  0.6208 -1.0140  0.4891 -0.9596
# 3      2.5130 -0.1470  0.3183 -0.0179 -0.7292 -0.4748 -0.2785 -1.3360 -0.8703
# 4      0.4460 -0.4033 -0.5549  0.2064  0.0216  1.5880 -1.0360  3.5090 -2.2770
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 23809  0.3944  0.3674  0.2919 -0.3602  0.7585  0.0378  1.0520  0.5638  0.0092
# 23810 -0.2253 -0.3340  0.7924  0.7409 -0.2976  0.1948 -0.4302 -0.0304  0.2858
# 23811 -0.7818  0.4668 -0.3064  0.0261  0.7024  0.2076 -0.1118  2.5400  0.1019
# 23812  0.9759  0.3770 -0.1667 -1.9070 -0.7880 -0.2524  1.3980 -0.4577  1.2790
# 23813  0.0056 -0.1083  0.7710  0.4409 -0.3823 -0.7455  0.3406  1.4670 -2.1350
#
#         g-200   g-201   g-202   g-203   g-204   g-205   g-206   g-207   g-208  \
# 0      2.0720  0.4171  0.2383  1.0990 -0.2268 -0.3183  0.5875 -0.2213 -0.8059
# 1      1.8500  0.0767  0.4833 -0.6428  0.8914 -0.6113 -1.1600 -0.5689 -0.3027
# 2      0.6812  0.8989  1.1700 -0.0548  0.0158  0.3535  0.4584 -0.2650 -0.7341
# 3      0.3079  1.0300  0.6138 -0.0781  0.6745  1.4640  0.1835  1.5390  0.7044
# 4      0.8582 -0.3519  0.1611 -0.6091  0.6349  2.5350  0.8124  0.4877  0.5398
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 23809 -0.5697 -0.0474 -1.0320  0.6841 -0.0931  0.1199  0.8176  0.6554  0.0928
# 23810  0.2069 -1.0560  1.7440  0.7027 -0.2622 -0.9029  0.1338  0.9784  0.2384
# 23811  0.2299  0.4774 -0.5097  0.4247  0.0378  0.2092 -0.6286  0.5109 -0.8677
# 23812 -0.5105  0.0583 -0.0592  2.2430  0.0488  1.3210 -3.5220  1.7750 -1.4230
# 23813 -1.0950 -1.5120  1.6970 -0.2525 -0.0158 -1.3610  1.1900  0.3465  2.0160
#
#         g-209   g-210   g-211   g-212   g-213   g-214   g-215   g-216   g-217  \
# 0      1.4560 -0.3744 -0.5810  0.7226  0.1093  0.7356 -1.2170  0.6242  0.7148
# 1     -0.1273 -0.8117  1.0240  0.3938  0.1875  0.2138  1.4080  0.5441  0.8406
# 2     -0.2659 -0.2204 -0.2573 -0.0987  0.0000 -0.9180 -0.4061 -0.1563 -0.5587
# 3     -0.4105  2.2950 -0.5759 -1.1730  0.0000 -0.7379  0.1739 -0.8528 -0.7338
# 4     -1.6940  0.9118 -0.0297 -0.8432 -0.6745 -0.1088 -0.2959  0.0000 -3.3670
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 23809 -0.9964  0.5615 -0.7996  0.4092 -1.0120 -1.3500  0.0471 -0.2314 -0.2148
# 23810  0.3452  0.6737  0.1436 -0.8885  0.2521 -0.4765  0.6326 -0.3690  0.5493
# 23811  0.6845  0.0952 -0.3551 -0.4820  0.0000  0.1243  0.0432  1.1940 -0.1543
# 23812  0.5367 -0.2465  0.6512  0.1467 -0.2290  0.5117 -1.1030  1.2890 -1.3960
# 23813 -0.1915 -0.5801 -0.7509  0.8092  0.7261 -1.4210 -2.4760  0.8249  0.1740
#
#         g-218   g-219   g-220   g-221   g-222   g-223   g-224   g-225   g-226  \
# 0      0.3128  0.2482 -1.0320 -0.5883 -1.9170 -0.2457  0.5389 -0.2066 -0.6200
# 1     -0.9672 -0.4611  0.1144  1.2280  0.1734  0.8120  0.9384  0.4147 -0.0678
# 2      0.7254 -0.1942  0.7268  0.4797  0.2154 -0.4764  0.1271  1.0900  0.9388
# 3     -0.7139  0.2921  0.4294  0.7911  0.5141 -1.2560  1.3320  1.0130 -0.2829
# 4      0.6184 -0.5558 -1.8510  0.8816 -0.4465 -0.1110  0.9283  0.4013  0.4805
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 23809  0.1737  0.1666  0.9562  0.0984  0.1823 -0.0532  0.6066  0.3174 -0.8550
# 23810 -0.4474  0.9524  1.1090 -0.0276 -1.5350 -0.0877  0.4570 -0.0698  3.5270
# 23811  1.0150 -0.1977  1.5450 -0.3567  0.1166 -0.5480 -0.8828 -0.3282 -1.4350
# 23812  0.6980  0.2283 -0.6748  0.5407  0.5444  0.0851 -1.5030 -1.1670 -0.8277
# 23813  1.0160  0.0000  1.0030  1.2610 -0.2534 -1.3130 -1.4440 -0.0165  0.5996
#
#         g-227   g-228   g-229   g-230   g-231   g-232   g-233   g-234   g-235  \
# 0      0.9635  1.1080 -0.0549  0.8528 -1.6510  0.1414 -0.2369  0.2736  0.1218
# 1      0.3877 -0.0554  0.5726 -0.2251 -0.3640  0.2817 -1.4580  0.4062 -0.5457
# 2     -0.5565  0.0423 -0.0731 -0.9985 -0.3970  0.2657 -0.8142  0.4578 -1.0520
# 3     -0.9621 -0.6012 -0.0755 -0.2506  0.4848 -1.0020 -0.3075  0.7056 -1.1260
# 4     -0.4941  0.5843 -0.2956 -0.5784  0.2703 -1.2210  0.2981  0.5394 -0.2124
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 23809 -0.0775  0.4864 -0.1222 -0.7738  1.0110 -0.4385 -0.7278 -0.3058 -1.2650
# 23810 -0.3419 -0.6271 -0.7327 -0.6486  0.0221 -0.2200  0.3453 -0.0863  0.4613
# 23811  0.3184 -0.2901  0.4711  0.2669  0.4257  0.3223 -0.4434  0.2051  0.5712
# 23812 -0.0391 -2.8130  0.3150 -0.6884  2.9040 -0.0511  0.8124  0.7214  0.9536
# 23813  0.1815 -0.6656  0.8388 -0.3080  1.4190  1.3890  2.0560  0.4115 -1.8370
#
#         g-236   g-237   g-238   g-239   g-240   g-241   g-242   g-243   g-244  \
# 0     -0.3546 -0.1706  0.2143  0.2421  0.0236  0.5628  0.4498 -1.2160  0.1905
# 1      0.0207  0.3992  0.0000 -1.6820 -0.5257  0.0354 -0.9122  0.5680 -0.1172
# 2      1.0170  0.2057  0.0000 -0.6368  0.0580  0.0256  0.3221  1.0280  0.3711
# 3     -0.8238  0.6757 -2.9920 -0.8815 -0.1069 -1.8660 -1.6800  0.8285 -0.2857
# 4     -1.7750  0.6448 -0.4229  1.1780 -0.1187  1.3120 -0.3824  0.2817 -0.4712
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 23809 -0.1223  0.5932  0.4401  0.9992  0.6550  0.1493 -0.5486  0.4162 -0.1112
# 23810  0.1154 -0.1486  0.2163 -0.5590  0.0158  0.6588 -0.3516 -0.8690 -0.2807
# 23811  0.1425 -0.0546 -1.1800 -0.4866 -0.8174 -0.3156  0.1517  0.1239  0.2954
# 23812 -2.3230 -0.8832 -0.3372 -1.6410 -0.7581  1.3150  1.4520 -0.5973 -0.2607
# 23813 -1.0480 -1.0580 -0.6431 -0.1234 -0.8566 -4.0900  2.2950  0.6550  0.5231
#
#        ...   g-622   g-623   g-624   g-625   g-626   g-627   g-628   g-629  \
# 0      ...  0.6308  0.7729 -0.0072  0.2032 -0.3999  0.4572 -0.8976  0.2599
# 1      ... -1.9270  0.7375 -0.5561  0.2121  0.1149 -0.1857 -0.0585 -1.1910
# 2      ... -0.6763 -1.0520  1.2730 -0.3368 -0.9114 -0.7419  0.6620 -0.3058
# 3      ... -1.2350 -0.1629 -1.3350  0.4012 -1.1110 -0.9854  2.8250  0.0419
# 4      ... -0.3649 -0.9032 -0.1633 -1.3880 -1.1370 -1.2700 -0.6423 -1.3100
# ...    ...     ...     ...     ...     ...     ...     ...     ...     ...
# 23809  ... -0.0331  0.2022 -0.1430  0.2184  0.8674 -0.2560 -0.3902  0.2042
# 23810  ...  0.5192 -0.2905 -0.7866 -0.0474  0.6084  0.3883 -0.5070  0.0809
# 23811  ... -0.1594  0.2201 -0.4017 -1.3980  0.7170  0.4711  0.0062 -0.3724
# 23812  ...  0.6265  2.0830  1.4920  1.2340  0.1284  2.0250  0.5246  0.8814
# 23813  ...  1.0030 -0.8307 -0.1297  1.0440 -1.2670  0.9257  1.1320  0.9241
#
#         g-630   g-631   g-632   g-633   g-634   g-635   g-636   g-637   g-638  \
# 0      0.8406  0.6590  0.5739 -1.0410  0.2930 -0.2461 -0.1803 -0.3313 -0.8521
# 1     -0.0211  2.0930 -0.1148  0.5500 -0.2247 -0.2341  0.1500  1.0330  0.4735
# 2      0.7158  1.6390 -0.1177  0.5713  0.8512  0.7849 -0.3873 -0.4874  0.8361
# 3     -0.2128 -0.8987 -1.3500  0.5189  1.5050  0.7685 -0.6352 -0.0799 -0.9627
# 4     -1.6090  0.9920  1.1970  1.1150 -0.9618 -0.3988 -0.0109  0.3399 -0.5405
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 23809  0.4116  0.4956  0.1438  0.4882 -0.1032 -0.1968 -0.4359  0.0415  0.5245
# 23810  0.5209  0.1327  0.5694 -0.1793  0.8077 -0.5091  0.4528 -0.0175 -0.5027
# 23811 -0.6092  0.5194  0.0560 -0.1002 -0.9655  0.0861 -0.5927 -0.3103 -0.1867
# 23812  1.6510  1.2110  1.8110 -1.5130  1.1520 -0.7842  0.4585  0.2975 -0.9039
# 23813  1.7870 -0.2997 -1.6310  0.0147 -1.0430 -1.9860 -0.5507 -1.3420 -1.1510
#
#         g-639   g-640   g-641   g-642   g-643   g-644   g-645   g-646   g-647  \
# 0      0.0299 -1.6130  0.0490  0.5186 -0.7712  0.1361 -0.5311  0.8418 -0.0203
# 1     -0.3925  1.0250 -0.4841 -0.2616 -0.2097  1.6210 -0.0198 -0.3301 -0.7962
# 2      0.8780 -0.2979 -0.6863  0.2327  0.9903 -0.3399 -0.5250  0.0083 -0.6169
# 3      0.0909  2.3190 -0.1951 -1.2550  0.6816 -0.9182  1.4530  0.4617 -0.1585
# 4      1.1190  0.6789  0.3917 -1.9460 -0.2215 -0.1782 -1.0270 -0.4773 -1.5490
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 23809 -0.0391 -0.4124 -0.7467  0.6205  0.1016 -1.4950 -0.4007  0.3868  0.1453
# 23810  1.8590 -0.5993 -0.5353 -0.0657  0.9826  1.0250 -0.8907 -0.3235  0.5994
# 23811  0.1757  0.2843 -0.3720 -0.3856 -0.5768 -0.6761 -0.7630  1.4560 -0.5807
# 23812  1.0420 -1.0340 -2.1420 -2.9060  0.5874 -0.2734  0.3979 -0.5861  1.1040
# 23813 -0.5775 -2.1000  0.6550 -0.1703 -1.2610 -3.4500  1.3490  1.5080  1.2020
#
#         g-648   g-649   g-650   g-651   g-652   g-653   g-654   g-655   g-656  \
# 0      0.0685 -0.2004 -0.3432 -0.8311 -0.2598  0.8483  0.6825  0.4016  0.2968
# 1     -0.3305  0.8353 -0.0824  0.2448 -0.6899  0.0095 -0.2209 -0.4061 -0.2806
# 2      1.3990  0.1680 -0.2512  0.4597  0.5315  0.7145  0.3622  0.0651 -0.3092
# 3      0.1581  0.2589 -1.3220 -1.3490  1.6700  1.6140 -0.0307  0.1174 -4.2470
# 4     -0.9117 -0.7926 -1.1970  0.8247  0.4431  1.4850 -0.0666  0.7227 -0.8094
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 23809 -0.1250  0.5008 -0.3392  0.4216  0.3956 -0.0897  0.8781  1.7930  0.0530
# 23810 -0.1828 -2.2330  0.0817 -0.2508  1.0230 -0.0623 -0.0145  0.7252  0.4927
# 23811 -0.7802  1.0050 -1.7650 -0.0138  0.6883 -0.4447 -0.0587  0.2458 -0.2312
# 23812 -0.4701 -0.4409  0.0780 -0.1214 -1.2180  1.0940  1.1300  1.4680 -0.1565
# 23813  0.8674 -0.8411 -1.0580 -2.4900  2.1810 -1.3390  0.7744  0.2740  0.7950
#
#         g-657   g-658   g-659   g-660   g-661   g-662   g-663   g-664   g-665  \
# 0     -0.6905  0.1019 -0.9237 -0.1007  0.6118 -0.4484 -1.0010 -0.5325  0.8088
# 1      1.5450 -0.0336  0.8536 -0.3959 -0.0771  1.1700 -0.3825  1.2050 -0.2530
# 2      1.7750  0.5993  0.4922 -0.8939 -0.1007 -0.1343  1.1520  0.1996 -0.4331
# 3      0.1192 -0.2344 -0.2993 -0.7514 -2.3450  1.3640  1.0830 -0.2562 -0.5434
# 4      0.4121  0.2566  1.0350 -0.6698 -1.0020 -0.7150  0.9726 -0.0550 -0.8861
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 23809  0.5556 -0.4818  0.4417  0.7350 -0.2797  0.3966  1.6340  0.4004  0.9305
# 23810  0.2334  1.3110 -0.0964 -0.1247  0.2991  0.1574  0.1550  0.4484  1.2610
# 23811 -0.1271  0.1244 -0.1973 -1.1690  0.4916 -0.9563 -0.3904 -0.2675  1.2010
# 23812 -1.2140 -0.3562 -2.8080  1.1970  1.6600 -0.8123 -0.0730 -4.8910  2.5380
# 23813  0.2298  0.6144 -0.5056  1.1730  0.2254 -0.8856 -0.5875 -0.5454 -1.9890
#
#         g-666   g-667   g-668   g-669   g-670   g-671   g-672   g-673  \
# 0     -0.3570  1.3580  0.9664  0.6891 -0.5659 -1.2160  0.0260  2.0740
# 1     -0.1584  0.3260  0.0056 -0.8074 -0.3990  0.5275  0.1397 -0.8016
# 2      0.1165 -1.0320 -1.2070  0.4614  0.0810 -0.2468 -1.0270  2.1400
# 3      0.1641 -0.6745 -1.4150 -1.3860 -1.0970  1.3760 -3.5480 -0.7292
# 4      0.7264  1.0160  0.4907  1.0350  0.1357  0.5929 -1.7070 -0.3966
# ...       ...     ...     ...     ...     ...     ...     ...     ...
# 23809  0.3075 -0.5315 -0.3193  0.4397 -0.9003 -0.4316 -0.1477  0.4352
# 23810  1.1440  0.0027 -0.1467  0.5941 -0.6233 -0.7966  0.5450  0.3906
# 23811 -0.3607 -0.4377  0.2185  0.4979  0.4162  0.1895 -0.2680  0.1299
# 23812  0.2109 -1.1490  0.3620  0.1544  0.1839 -2.8810 -2.4680 -0.3217
# 23813  1.1500 -0.1355  0.4737  1.4180 -2.3050  0.0428 -0.7581  1.3250
#
#          g-674   g-675   g-676   g-677   g-678   g-679   g-680   g-681  \
# 0       0.1510  0.4802 -0.0777 -0.4704  0.1794  0.1726 -0.2420  0.6410
# 1       0.0213  0.7234  0.3140  0.1219  0.2062  0.0692  0.4442 -0.5133
# 2      -0.7917 -1.2830 -0.3885  0.8156 -0.9331 -0.7458 -0.5182 -0.2459
# 3      -2.3340  0.3811 -0.2867 -0.5258 -1.7020 -0.5638 -3.3060 -0.3645
# 4     -10.0000  0.0472  0.5929  1.3980  0.8074 -1.6370  0.8040 -1.6680
# ...        ...     ...     ...     ...     ...     ...     ...     ...
# 23809  -0.6190  0.0146 -0.4130 -0.2326 -0.4739  0.0549 -0.4198 -0.1749
# 23810   0.7237 -0.3868 -0.0683 -0.2884  0.3496  0.4878 -0.2831  0.3683
# 23811   0.5271 -0.4688 -0.8221  0.7166  0.2011 -0.0536 -0.4343 -0.5125
# 23812   0.1652 -0.5193  0.0508  0.1693  0.7551 -0.0297 -0.4714  1.2580
# 23813  -1.6860  0.7490 -0.6610 -0.3967  0.5939 -1.1380 -0.7580  1.1010
#
#         g-682   g-683   g-684   g-685   g-686   g-687   g-688   g-689   g-690  \
# 0      0.4676 -0.5658  0.0339 -0.8148 -0.8473 -0.4542  0.2070 -0.9777 -0.0127
# 1      0.4945 -0.0779 -0.6745 -0.8910 -2.4460  0.6951  0.1032  0.1847 -0.9964
# 2      1.7540 -0.4985  0.1818 -1.9020 -3.6980  0.1066  1.3720  0.3859  0.8492
# 3     -0.5911  1.4210  0.1478  1.6550  0.2889  1.1170 -0.0378  2.3980  1.2510
# 4      0.9047  1.9140 -2.1710  1.4720  0.0429  0.7096 -0.4162  0.7050 -0.3331
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 23809  1.1510 -0.9018  0.5240 -3.5030  0.4196 -0.8036 -0.0647  1.8910  1.1310
# 23810  1.6740 -0.2883  0.1017 -0.0294  0.2746 -0.4499 -0.2684 -0.3422 -0.4365
# 23811 -1.3270  0.7814  0.2256  0.5541  0.0232  0.2919  0.0374 -0.2748 -0.0692
# 23812  1.1280  0.6955 -0.1115  0.0031 -0.4415 -0.9855 -0.3386  0.6497 -1.2020
# 23813  0.2788  0.6064  0.3106  1.2420  0.6978  0.3966  0.5396 -3.1370 -0.0695
#
#         g-691   g-692   g-693   g-694   g-695   g-696   g-697   g-698   g-699  \
# 0      0.0926 -0.2848 -0.9096  0.8706  1.5650  0.0388  0.5303 -0.1335 -1.0710
# 1      0.2310 -0.4867  0.0663 -4.1870  0.6669  0.8576 -0.4833 -0.0817  2.2200
# 2      1.6340  0.3321  1.1220  0.5421 -1.1240 -0.3101 -0.6470  0.4192 -0.6892
# 3      0.7589  1.4650  0.1003 -0.5949  0.4992 -0.7242 -0.5878  0.9478 -0.7887
# 4      0.3867 -0.5725  0.9043 -0.4639  1.0570  0.2984 -0.1268  0.8745 -0.3670
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 23809  0.5666  0.0171 -0.4247  0.0539 -0.2870  0.3143  0.8571  0.0650  0.0641
# 23810 -0.9912  1.0870  0.0902  0.3192  1.6270  0.8910 -0.2064  1.0850 -0.9400
# 23811 -0.8726 -0.1273  0.6549 -0.9310 -0.1436  1.4480 -1.4650  0.4024  0.4083
# 23812  1.2420 -0.3415  1.4890 -0.1997 -0.2070  1.6750 -1.1830 -2.3530  1.1030
# 23813  0.8381 -1.2890 -0.2743  0.6195  1.3610 -1.7340 -0.7625 -0.3498 -0.2491
#
#         g-700   g-701   g-702   g-703   g-704   g-705   g-706   g-707   g-708  \
# 0      1.3660  0.3547  1.1850 -0.4955  0.1167  0.0252  0.1475 -0.1656 -0.7887
# 1     -0.8233 -1.0760 -0.2645 -0.7521  0.8955  0.4854  0.1402  0.1514  0.0730
# 2      0.1765 -0.1348 -0.1582  0.4049  0.2967  0.6300  0.7751  0.0000  0.7150
# 3     -0.8408 -0.2256  0.3293 -0.0092 -1.1560 -1.2300 -1.3140  0.0000  2.2010
# 4     -0.6745  0.2748  0.8101  1.7040 -0.3871 -0.6745 -0.7185  0.0000 -0.3093
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 23809  0.2770  0.1897 -0.5592  1.1490 -0.3110  1.2080  0.6561  0.1492  0.1166
# 23810  0.5081 -0.4044 -0.0404  2.2310  0.9308 -0.9715 -1.0710  3.8770 -0.2836
# 23811 -0.1694 -0.2688 -0.0930  0.1096 -0.1312 -0.3032  0.0183  5.3980 -0.3971
# 23812 -0.5813 -1.6650 -0.7146 -2.6980 -0.2016 -0.8828 -1.2250  0.0000 -0.6028
# 23813  2.8390  0.0911  1.8290  0.3108  0.2274  0.5819 -0.8326  0.0000 -1.2240
#
#         g-709   g-710   g-711   g-712   g-713   g-714   g-715   g-716   g-717  \
# 0     -0.1821 -0.0314 -0.4589 -0.2511 -0.8571  0.7007  0.9829  1.3150  0.4647
# 1      0.4431  0.5035  0.9635  0.6474  0.4754 -0.3977 -0.0720 -0.7758  0.2326
# 2     -0.3821 -0.0208  0.9317 -0.1150  0.2530 -0.5545 -0.7061 -0.4234  0.2350
# 3     -0.1639 -0.7305  0.9258 -1.0620  0.6889 -0.9377 -0.7624  0.0610 -1.3920
# 4      0.0614 -1.0190  0.9962 -0.9680  1.4920  0.2381 -0.0645 -0.2846  1.3330
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 23809 -0.6728  0.2537 -0.1956  0.3389  0.0267  1.0790  0.6822 -0.6991 -0.0629
# 23810  0.4914 -1.1900 -0.0467  0.4231  0.1543 -0.4956  1.4370 -0.3234  0.0706
# 23811 -0.1735 -0.2574  0.1945 -0.7279 -0.3115  1.0980 -1.7530 -0.1619 -0.8313
# 23812  0.5472  0.9024 -0.9441  0.9734  0.8423  0.2538  0.4423  0.8278  1.6740
# 23813  0.0187 -1.1430 -1.4520  0.0066  0.4252  0.8937 -0.7493  1.3880 -1.3680
#
#         g-718   g-719   g-720   g-721   g-722   g-723   g-724   g-725   g-726  \
# 0     -0.3811 -2.9720 -0.3604  0.0570  0.3263  0.8888 -0.7433 -0.4647 -0.2641
# 1     -0.4880  0.0326 -0.3358  0.0632 -0.0542 -0.2321 -0.4092  0.2212  0.7369
# 2     -0.1255  0.3519  0.7924  0.8877  1.0540  0.5625 -0.4162 -0.1915 -0.2098
# 3      0.2704 -0.3988  1.0400  0.5012  0.5485  1.5170  0.7751  1.0230  1.8570
# 4      0.0000  0.6653  0.1693  0.0000 -0.4773  0.0743  0.4294 -0.8562  0.9180
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 23809  0.6071 -0.4070 -0.2127  0.4945 -0.2329 -0.4721  0.4514 -0.6751  0.4678
# 23810 -0.6255 -0.2113 -0.1820 -0.5365  0.7516  0.3460 -1.0820  0.6263  1.6240
# 23811 -0.1895  0.8553 -1.4430 -0.7445  0.8507 -1.0180 -0.6114 -0.7214  0.0628
# 23812 -0.1461  0.6573 -0.4386  0.2283  1.2440  0.0890  1.4060 -0.4297 -1.1140
# 23813 -0.3885  1.4180 -1.3040  1.0370  0.7247  0.1692 -0.3711  0.7426  0.7062
#
#         g-727   g-728   g-729   g-730   g-731   g-732   g-733   g-734   g-735  \
# 0     -0.6593  1.0520  0.3921  0.1705 -0.5949 -0.9041 -0.8089  0.6598 -0.4772
# 1      0.8979 -0.5004 -0.3708  0.1372 -1.2270  3.1050  0.0204 -0.0961  0.2919
# 2      1.0540 -0.2885 -1.2540  0.2628  0.4860 -0.4954 -0.1840 -1.1110 -0.5649
# 3     -0.4721  0.5465  1.9580  0.3873  0.9512  0.2239  0.4428 -0.2822 -0.8175
# 4      0.4062  0.2048 -0.9851 -1.1220  0.9106 -0.2094  1.1270  0.1874 -0.0465
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 23809 -0.2865 -0.0869 -0.5062 -0.1876 -0.2318  0.3982 -0.1537 -0.3957  1.0370
# 23810 -0.5434 -1.0590 -0.8880 -0.6644 -0.6026  0.9713  0.5073  0.2552  0.2894
# 23811  0.4824 -0.2630 -0.3196 -0.6141 -0.7451 -0.5976 -0.6849 -0.6862 -0.0922
# 23812 -1.2530  2.1400  2.3870  0.6039 -0.2384 -0.4677 -0.5125  0.6954 -2.7690
# 23813 -2.0100 -0.6179  1.9710  1.5600  0.2088  1.4250 -0.4745 -1.1950 -1.2260
#
#         g-736   g-737   g-738   g-739   g-740   g-741   g-742   g-743   g-744  \
# 0      0.1289 -0.0297  0.4564 -0.1447  0.4683 -0.1722  0.9998  1.2860 -0.6166
# 1     -0.4584  0.0556  0.9844 -0.6653 -0.3092 -0.1507 -0.9481 -0.1966  0.8554
# 2     -0.2617  2.9120  2.7720  0.1523 -1.1230 -0.5340 -0.7937  0.3457 -0.6136
# 3      1.4930 -0.0711 -1.6250 -0.4317 -0.0239  0.5046 -0.8061  0.9736  1.2540
# 4      1.0560 -0.6324 -0.3651  0.9485 -0.6745  0.0479 -1.0470 -1.2440 -0.7675
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 23809  0.6222  1.5470 -0.0624  0.1023  0.2465  0.6802  0.5289  0.1255 -0.2395
# 23810 -0.3094  2.9370 -0.7162  0.4444 -0.4089 -0.2635  0.2614  0.8788 -0.8276
# 23811 -0.9769 -0.0931 -0.4010  1.4730  0.4372 -0.1711 -0.2151  0.6265 -0.5747
# 23812  0.7210  0.3261 -1.3160 -0.9186  1.3630 -0.9480 -0.2286  0.7634  1.0010
# 23813 -0.8440  2.9450 -0.2512 -0.2157 -0.1726  0.7089 -0.8355  2.2080 -0.2311
#
#         g-745   g-746   g-747   g-748   g-749   g-750   g-751   g-752   g-753  \
# 0      0.0963  1.6340 -0.8744  0.4931 -0.0283 -0.3110 -0.1117 -0.4528  1.3240
# 1      0.5839 -1.6840  0.0648  0.5845  0.0891 -0.5025 -0.1047  0.3764 -1.4800
# 2     -0.0706 -0.7474  0.1795 -0.4674 -0.1552  0.6338  0.5130 -0.3625  0.0873
# 3      2.0730  0.6604 -0.4758 -0.1766 -0.8959  0.6560 -0.0875  0.1082 -0.7158
# 4      0.2327  0.3698  1.4900  0.3632  1.4380 -0.5047 -0.2092 -0.4386 -1.1780
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 23809 -0.1544  0.6257  0.3508 -0.7258 -0.6351 -1.0200  0.1589 -0.3008  0.0423
# 23810 -2.4130  0.1505  0.3372 -2.5970  0.2835 -0.7155 -0.2361 -0.3432  0.6308
# 23811 -0.2041  0.5837 -1.2040  0.2896 -0.3467 -0.9851  0.2057 -0.0722 -0.4876
# 23812  1.9820 -0.3600  0.1271  0.8032 -1.9900  0.7946 -1.0310  0.9842  2.2030
# 23813  0.4585  1.5080 -1.5750  0.5712 -0.0712 -0.1244  0.3663 -0.8471  1.7350
#
#         g-754   g-755   g-756   g-757   g-758   g-759   g-760   g-761   g-762  \
# 0     -0.0503 -1.2750 -0.1750 -0.6972 -0.2720  0.2931  1.5280  0.3453 -0.5055
# 1     -0.2947  0.2745 -0.5234  0.1575 -0.1214  0.0476  0.1657  1.0310 -0.5338
# 2      0.2689 -0.2174  0.7069 -0.6456  0.6822  0.2237 -0.3601  1.2780  2.5770
# 3      0.0712 -0.1939  0.4286 -1.0220  0.9017  1.1750 -0.5760  0.7801 -0.1292
# 4      0.8236  1.0540  0.6745 -0.6354 -0.6745 -1.3780  0.7521 -0.9456 -0.6904
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 23809  0.3369 -0.6222  0.3070  0.3007  0.1275 -0.0176  0.8832  1.1980  0.7790
# 23810 -0.2580  2.7150 -0.4739  0.1783  0.4858 -0.2523 -0.5757  0.5157 -0.0858
# 23811  0.3832 -1.8220 -0.2816 -0.1603  0.4345  0.7097  0.3145 -0.7633  0.1796
# 23812 -0.3180  0.5809  0.0158  0.8857 -2.3030  2.4360  0.4753 -5.5030 -0.1410
# 23813 -0.8691  1.0170 -0.4745 -1.5600  0.8000 -3.2640  1.5450 -0.4691 -0.5552
#
#         g-763   g-764   g-765   g-766   g-767   g-768   g-769   g-770   g-771  \
# 0     -0.3167  1.0930  0.0084  0.8611 -0.5582  0.3008  1.6490  0.2968 -0.0224
# 1      0.0224 -0.4831  0.2128 -0.6999 -0.1214 -0.1626 -0.3340 -0.3289 -0.2718
# 2      0.2356  1.3230 -1.3730 -0.2682  0.8427  0.5797  0.3143  0.8133  0.7923
# 3      3.4310  1.2720 -0.4733 -2.0560  0.5699  0.1996  0.4374  0.1588 -0.0343
# 4      2.0540 -0.3131 -0.0809  0.3910  1.7660 -1.0020 -0.7534  0.5000 -0.6269
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 23809  0.5393  0.4112 -0.5059  0.0240 -0.2297  0.7221  0.5099 -0.1423  0.3806
# 23810  0.3606 -0.0248  0.0672 -0.5901 -0.1022  0.5247  0.5438 -0.1875 -0.4751
# 23811  0.3488  0.0927  0.5166 -0.3099 -0.5946  0.9778  0.2326 -0.6191  0.3603
# 23812  1.9590  0.8224  1.2500 -3.1930 -2.8720  0.1794  0.3109 -0.3491 -0.4741
# 23813  3.6080  0.9145  0.8314  1.0610 -0.4017  1.5410  0.3633 -3.1970  2.2190
#
#           c-0     c-1     c-2     c-3     c-4     c-5     c-6     c-7     c-8  \
# 0     -0.0600  0.1083  0.6864  0.4043  0.4213 -0.6797  0.2888  0.4323 -0.3381
# 1      0.0927  0.2723  0.2772  0.7776  0.3679  0.5696  0.2835  1.4080  0.3745
# 2     -0.1312 -1.4640  0.3394 -1.7790  0.2188  0.5826 -0.7513  0.0543  0.7182
# 3     -0.3998 -4.5520 -2.7350 -1.9630 -2.8610 -1.2670 -2.5830 -0.5036 -3.1590
# 4     -0.3774  0.7364 -0.1659  0.2341  1.0060  0.3204 -0.0852 -0.2284 -0.2533
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 23809  0.4224  0.1871 -0.4822  0.3713  0.4754  0.9512  0.4650  0.3005  0.0338
# 23810  0.2144  0.4350  0.1174  1.3960 -0.6772  0.2316 -0.5396  0.0581  0.6067
# 23811  1.0650  0.6329  0.3742  0.1237  0.6147  0.4589 -0.2372  1.1160  0.4623
# 23812  0.5377  1.3240  0.9679  0.1419  1.2230  0.3404 -0.1589  0.8667  0.7749
# 23813 -2.3890 -2.0350 -1.1080 -6.2650 -4.1070 -2.0280 -3.4190 -1.3220 -1.9920
#
#           c-9    c-10    c-11    c-12    c-13    c-14    c-15    c-16    c-17  \
# 0      0.3407  0.9084  0.6857  1.0620  0.7602 -0.1048  0.3594  0.6376 -0.2798
# 1      0.6775  0.7787  0.2074  1.1110  0.2433  0.2010  0.7094 -0.4210 -0.2274
# 2     -0.4159  0.3084 -0.0899 -0.0397 -0.5077 -0.5072  0.0100 -0.6915  0.0643
# 3     -1.8510 -2.2730 -4.6920 -1.2750 -1.4970 -0.0156 -1.9350 -1.3430 -0.5252
# 4     -0.3174  0.9642 -0.0853  0.1559  0.1419  0.1197  0.6774  0.1332 -0.5176
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 23809 -0.7734  0.3922 -0.0028  1.3250  0.3832  1.4350 -0.3465 -0.6813 -0.0440
# 23810 -0.4622  0.1112  1.4440 -0.8000  0.3615 -0.4301 -0.0562 -0.2590 -1.3780
# 23811  0.2830  0.6260 -0.2559  0.5093  0.3384  0.8395  0.3992  0.0669  0.9208
# 23812 -0.1458  0.4287  0.6342 -0.3830 -0.0918 -0.1479  1.4290  0.2736  0.9842
# 23813 -1.6540 -4.0960 -1.9000 -0.4856 -5.0640 -2.4550 -3.4760 -1.1100 -1.9970
#
#          c-18    c-19    c-20    c-21    c-22    c-23    c-24    c-25    c-26  \
# 0     -0.4010  0.6842  1.1560  0.3522 -0.3971 -0.2115 -0.2687  0.5196  0.1594
# 1      0.4045  0.1138  0.9950  0.0087  0.4864 -0.0140  0.0164  0.1759  0.6654
# 2     -0.8927 -0.2048  0.0773  0.5971 -0.1602 -0.2028 -0.2216 -1.1380  0.3668
# 3     -2.7210 -0.2524  0.9197 -3.1220 -1.9180 -0.6761 -2.8360 -1.6890 -4.4990
# 4      0.1232  0.0827  0.6995  0.5953  1.0600 -0.4255  0.8624  1.0010  0.0840
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 23809  0.0016 -0.7588  0.5373 -0.3728  0.1439  0.3021 -0.0546  0.7490 -0.1772
# 23810 -0.3346  0.0869 -0.1766 -0.1957  0.8420 -0.9363 -0.6085  0.9446 -0.8192
# 23811 -0.1220 -0.1834  0.3320  0.0615  0.6909  0.0788  0.2697  0.6127  0.4435
# 23812  0.3394 -0.1685  0.3873 -0.1351 -1.0770  0.7400  0.7976  0.2998  0.2517
# 23813 -7.0460 -0.5438 -2.0450 -5.4260 -1.8990 -2.1730 -2.8110 -5.8430 -2.4340
#
#          c-27    c-28    c-29    c-30    c-31    c-32    c-33    c-34    c-35  \
# 0      0.8920  0.6485  0.6078  0.3799 -0.1727  0.3817  0.3600  0.5124 -0.1414
# 1      0.3556  0.8175  0.0474  0.5589  0.4481  0.1888  0.3712  0.7837  0.6860
# 2     -1.0620 -0.7736  0.6225  0.6274 -0.3038  0.1171 -0.0550 -0.0289  1.1740
# 3     -1.5190 -2.2730 -0.3250  0.1895 -2.4220  0.0670 -1.9870 -0.6482 -0.0023
# 4     -0.6553 -0.1093  0.0587  0.5490  0.6331  0.5227  0.2186  0.2781  0.8947
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 23809  1.0870  0.9235  0.7491  1.0560 -0.3548  0.4730  0.3669  0.3175  0.0836
# 23810  0.7525 -0.3499  0.2467 -0.2245  0.2532 -1.8510  0.0680  0.8498 -0.5285
# 23811  0.7225  0.8947  0.7414  0.7820 -0.0550  0.6533  0.6041  0.3308 -0.1120
# 23812  0.4569 -0.6226  0.2499  1.7530  0.2476  0.1594 -0.4389  0.9799 -0.5447
# 23813 -3.1980 -7.4720 -5.2850 -1.1590 -2.1180 -2.0940 -6.5930 -2.3650 -1.2020
#
#          c-36    c-37    c-38    c-39    c-40    c-41    c-42    c-43    c-44  \
# 0      0.6159  0.4689 -0.0773  0.4728 -0.0143 -0.5344  0.3578  0.3248  0.8903
# 1      0.4123  0.1560 -0.1203 -1.2780  0.6743  0.7358  0.1334 -0.5193  0.2281
# 2     -0.7937 -1.0610 -0.6409  0.3884 -1.0330 -0.0055  0.1212 -0.7020 -0.7065
# 3     -1.9930 -0.8042 -3.6160 -0.3487 -1.2560 -2.7220 -2.1970 -2.9030 -1.1030
# 4     -0.0202  0.5966  0.2249  0.5671  0.6382 -0.3909  0.7040  0.1462  0.0655
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 23809 -0.0980 -0.2717 -0.2635 -0.0231  0.1908  0.7024  0.6459 -0.8431 -0.1879
# 23810  0.3788  0.2031  0.9963  0.0844  0.5501  0.7954 -0.7949  0.5596 -0.4925
# 23811  0.5269  1.0220  0.3622  0.5912  0.6455 -0.1857  0.0759  0.2548  1.0260
# 23812  0.1770  1.2550  0.4623 -0.8128  0.9177  0.7495 -0.4439  0.7247  0.7867
# 23813 -1.1160 -1.8450 -2.6360 -5.8560 -5.1110 -2.3940 -2.6480 -1.6790 -0.8367
#
#          c-45    c-46    c-47    c-48    c-49    c-50    c-51    c-52    c-53  \
# 0      0.3431  1.0340  1.3070 -1.0230  0.7709  0.7180  0.0546 -0.9013  0.0471
# 1      0.0158 -0.5658  0.6065  0.6259  0.4716  0.0453  0.5036  1.0750  0.2111
# 2     -0.5192 -0.3181  0.1787  0.3354  0.1349 -0.3569 -0.8229 -0.2778  0.7047
# 3     -2.3020 -2.0030 -1.3390 -3.0160 -3.0040 -2.8880 -1.4910 -1.7960 -1.3670
# 4     -0.5605  0.5903 -0.2353 -0.1285 -0.1740  0.3559  0.0204  0.3385 -0.2290
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 23809  0.8394  0.5270 -0.6097  0.7577  0.0365  0.1181  1.2150 -0.3222  0.4523
# 23810  0.4604 -0.5548 -0.7309  0.2137 -0.1295 -0.1987 -0.6876 -0.0909 -1.3510
# 23811 -0.4440  0.4661  0.2907  0.4696  0.4874  0.4221  0.9822  0.5505 -0.0070
# 23812  0.7962  0.3351  0.5460 -0.7703 -0.1128  0.9409 -0.0084  0.7227 -0.0148
# 23813 -3.9370 -3.0640 -0.7138 -1.6730 -1.4890 -6.0290 -3.0870 -1.2320 -0.0765
#
#          c-54    c-55    c-56    c-57    c-58    c-59    c-60    c-61    c-62  \
# 0      0.3927 -0.1148 -0.0476 -0.1612  0.1493 -0.2094  0.4805  0.4965  0.3680
# 1      0.4759  0.1408  0.8763  0.4611  0.8784 -0.4291  0.4083  0.0319  0.3905
# 2     -0.9726 -0.0553 -0.2143  0.0187  0.4497  0.2585 -0.5477 -0.7576 -0.0444
# 3     -2.7830 -3.3290  0.1071 -2.5430  0.3747 -1.7540 -2.1220 -0.3752 -2.3820
# 4     -0.3813 -0.0856  1.1080 -0.4190  0.8741  0.9074 -0.2274  0.3215  0.1535
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 23809  0.3221  0.9701 -0.5324  0.0972  0.2197  0.1319  0.0807  0.4024 -0.0895
# 23810  0.6093  0.3644  0.4062 -0.1491  0.1923  0.2133  0.1410  1.2640 -0.8663
# 23811  0.2489  0.8001 -0.6212 -0.4445  0.8877  0.4520  0.6845  0.7127  0.7294
# 23812  0.4159  0.3656  1.2830  1.3380 -0.3524  0.3661  0.3360 -0.6136  0.5011
# 23813 -3.7340 -4.8580 -2.4110 -3.4760 -1.8560 -5.1000 -6.9170 -1.8640 -2.5090
#
#          c-63    c-64    c-65    c-66    c-67    c-68    c-69    c-70    c-71  \
# 0      0.8427  0.1042  0.1403  0.1758  1.2570 -0.5979  1.2250 -0.0553  0.7351
# 1      0.7099  0.2912  0.4151 -0.2840 -0.3104 -0.6373  0.2887 -0.0765  0.2539
# 2      0.1894 -0.0014 -2.3640 -0.4682  0.1210 -0.5177 -0.0604  0.1682 -0.4436
# 3     -3.7350 -2.9740 -1.4930 -1.6600 -3.1660  0.2816 -0.2990 -1.1870 -0.5044
# 4     -0.4640 -0.5943  0.3973  0.1500  0.5178  0.5159  0.6091  0.1813 -0.4249
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 23809  0.4420  0.9641 -0.1846 -0.0014  0.3154 -0.2071 -0.6158 -0.2977  0.0992
# 23810  0.8129 -0.1514 -0.4652 -0.7390 -1.3270  0.9925  1.0570 -0.3355 -0.2555
# 23811  0.4718 -0.2020  0.2783  0.4934  0.4144  0.5449  1.4690 -0.6142  0.6068
# 23812  0.9261  0.4419  0.0295  0.4220  0.4677 -0.1184  0.4524  0.4135  0.1356
# 23813 -4.7130 -1.7250 -3.8650 -3.0800 -4.1530 -1.2030 -1.1690 -4.1460 -1.2670
#
#          c-72    c-73    c-74    c-75    c-76    c-77    c-78    c-79    c-80  \
# 0      0.5810  0.9590  0.2427  0.0495  0.4141  0.8432  0.6162 -0.7318  1.2120
# 1      0.4443  0.5932  0.2031  0.7639  0.5499 -0.3322 -0.0977  0.4329 -0.2782
# 2      0.4963  0.1363  0.3335  0.9760 -0.0427 -0.1235  0.0959  0.0690 -0.9416
# 3     -1.7750 -1.6120 -0.9215 -1.0810 -3.0520 -3.4470 -2.7740 -1.8460 -0.5568
# 4      0.7832  0.6529  0.5648  0.4817  0.0587  0.5303  0.6376 -0.3966 -1.4950
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 23809  0.6838  0.5259  0.7882  0.3119 -0.7697  0.2203 -1.0710  0.5979  0.0848
# 23810  0.8219  0.6995 -0.2942  0.2408 -0.7781 -0.0929 -0.0329  0.0781 -1.4440
# 23811  0.3434  0.9880 -0.0468 -0.1882 -0.0087 -0.0356  0.5718  0.4971  0.1057
# 23812 -0.5801  0.0411  1.0240  1.0340 -0.0270 -0.4194  0.7403 -0.6793 -0.1423
# 23813 -1.1300 -2.4390  0.1591 -2.2490 -2.5860 -1.9520 -2.1810 -4.6690 -3.9450
#
#          c-81    c-82    c-83    c-84    c-85    c-86    c-87    c-88    c-89  \
# 0      0.6362 -0.4427  0.1288  1.4840  0.1799  0.5367 -0.1111 -1.0120  0.6685
# 1      0.7827  0.5934  0.3402  0.1499  0.4420  0.9366  0.8193 -0.4236  0.3192
# 2     -0.7548 -0.1109 -0.6272  0.3019  0.1172  0.1093 -0.3113  0.3019 -0.0873
# 3     -3.3960 -2.9510 -1.1550 -3.2620 -1.5390 -2.4600 -0.9417 -1.5550  0.2431
# 4     -0.9625 -0.0541  0.6273  0.4563  0.0698  0.8134  0.1924  0.6054 -0.1824
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 23809 -0.2555  0.6293  1.1660  0.3329  0.2754  0.4108 -0.1252 -0.2340  0.2267
# 23810 -0.0921  0.3188 -1.1080  0.4895 -0.2144  1.0960  0.3335  0.4444 -1.1130
# 23811  0.2111  0.6992  0.0708  0.6169  0.2248  0.5994  0.2689  0.0305  1.2320
# 23812  0.7307  0.7946 -0.0650  0.9038  0.2324  0.9676  1.0940  0.4290  0.5187
# 23813 -2.9560 -2.7930 -2.1560 -2.4100 -1.8190 -3.3480 -0.1414 -2.6430 -2.5810
#
#          c-90    c-91    c-92    c-93    c-94    c-95    c-96    c-97    c-98  \
# 0      0.2862  0.2584  0.8076  0.5523 -0.1912  0.6584 -0.3981  0.2139  0.3801
# 1     -0.4265  0.7543  0.4708  0.0230  0.2957  0.4899  0.1522  0.1241  0.6077
# 2     -0.7250 -0.6297  0.6103  0.0223 -1.3240 -0.3174 -0.6417 -0.2187 -1.4080
# 3     -2.0990 -0.6441 -5.6300 -1.3780 -0.8632 -1.2880 -1.6210 -0.8784 -0.3876
# 4      0.0042  0.0048  0.6670  1.0690  0.5523 -0.3031  0.1094  0.2885 -0.3786
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 23809  0.1969  0.0262 -0.8121  0.3434  0.5372 -0.3246  0.0631  0.9171  0.5258
# 23810  0.4286  0.4426  0.0423 -0.3195 -0.8086 -0.9798 -0.2084 -0.1224 -0.2715
# 23811  0.5409  0.3755  0.7343  0.2807  0.4116  0.6422  0.2256  0.7592  0.6656
# 23812 -0.1105  0.4258 -0.2012  0.1506  1.5230  0.7101  0.1732  0.7015 -0.6290
# 23813 -3.3890 -1.7450 -6.6300 -4.0950 -7.3860 -1.4160 -3.5770 -0.4775 -2.1500
#
#          c-99
# 0      0.4176
# 1      0.7371
# 2      0.6931
# 3     -0.8154
# 4      0.7125
# ...       ...
# 23809  0.4680
# 23810  0.3689
# 23811  0.3808
# 23812  0.0740
# 23813 -4.2520
#
# [23814 rows x 877 columns]

# %% [markdown]
# ###Desafio 01: Investigar por que a classe tratamento é tão desbalanceada?
#
# ###DEsafio 02: Plotar as 5 últimas linhas da tabela
#
# ###Desafio 03: Proporção das classes tratamento.
#
# ###Desafio 04: Quantas tipos de drogas foram investigados.
#
# ###Desafio 05: Procurar na documentação o método query(pandas).
#
# ###Desafio 06: Renomear as colunas tirando o hífen.
#
# ###Desafio 07: Deixar os gráficos bonitões. (Matplotlib.pyplot) ( colocar título, lable,...)
#
# ###Desafio 08: Resumo do que você aprendeu com os dados

# %% [markdown]
# ## **Desafio 01**: Investigar por que a classe tratamento é tão desbalanceada?

# %% [markdown]
# Pela live dos instrutores seriam variáveis livres as colunas 'tratamento', 'tempo', 'dose' e 'droga'.  Se quisermos estudar o efeito do uso de drogas numa determinada cultura de bactérias, precisamos tentar reproduzir as condições normais.  Provavelmente isto foi feito com a substância de código cacb2b860 que se supõe ser o líquido base em que houve o cultivo sem a adição das drogas que se deseja testar.  O fato de se ter um desbalanceamento tão grande se deve ser imputado ao grande número de drogas a serem avaliadas.
# Foi possível observar que algumas drogas tais como 87d714366, 9f80f3f77, 8b87a7a83 e 5628cb3ee foram bem mais examinadas, enquanto que outras, tais como f5c443039 apareceram apenas uma vez.

# %%
import numpy as np

pd.options.display.width = 0
np.set_printoptions(formatter={'int_kind': '{:,}'.format})

pd.set_option('display.min_rows', 10)
pd.set_option('display.max_rows', 50)
print(dados.columns)
display(
    dados[dados['tratamento'] == 'com_controle']['droga'].value_counts(), # mostra que cacb2b860 é a droga de controle
    dados[dados['tratamento'] == 'com_droga']['droga'].count(), # número de registros com drogas ativas
    dados[dados['tratamento'] == 'com_droga']['droga'].value_counts().sort_values(ascending=False),
    dados[dados['tratamento'] == 'com_droga']['droga'].value_counts().value_counts().sort_values(ascending=False), 
)
'''
A droga código cacb2b860 é usada como controle, pois quando o campo tratamento == com_controle a droga utilizada é cacb2b860.
'''
# Out:
# Index(['id', 'tratamento', 'tempo', 'dose', 'droga', 'g-0', 'g-1', 'g-2',
#        'g-3', 'g-4',
#        ...
#        'c-90', 'c-91', 'c-92', 'c-93', 'c-94', 'c-95', 'c-96', 'c-97', 'c-98',
#        'c-99'],
#       dtype='object', length=877)
# cacb2b860    1866
# Name: droga, dtype: int64
# 21948
# 87d714366    718
# 9f80f3f77    246
# 8b87a7a83    203
# 5628cb3ee    202
# d08af5d4b    196
#             ...
# a8ec8311e      1
# 0dedfb162      1
# 4a8eda087      1
# 40b490d82      1
# f5c443039      1
# Name: droga, Length: 3288, dtype: int64
# 6      2774
# 7       196
# 1       129
# 5        66
# 12       64
# 13       25
# 14        6
# 11        4
# 8         4
# 2         3
# 4         3
# 18        3
# 3         2
# 718       1
# 178       1
# 203       1
# 186       1
# 194       1
# 19        1
# 202       1
# 246       1
# 196       1
# Name: droga, dtype: int64
# '\nA droga código cacb2b860 é usada como controle, pois quando o campo tratamento == com_controle a droga utilizada é cacb2b860.\n'

# %% [markdown]
# ### **Desafio 02**: Plotar as 5 últimas linhas da tabela

# %%
dados.tail()
# Out:
#                  id    tratamento  tempo dose  ...  c-96  c-97  c-98  c-99
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.06  0.92  0.53  0.47
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.21 -0.12 -0.27  0.37
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.23  0.76  0.67  0.38
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.17  0.70 -0.63  0.07
# 23813  id_ffffdd77b     com_droga     72   D1  ... -3.58 -0.48 -2.15 -4.25
#
# [5 rows x 877 columns]

# %% [markdown]
# ### **Desafio 03**: Proporção das classes tratamento.

# %%
dados['tratamento'].value_counts(normalize=True)
# Out:
# com_droga       0.921643
# com_controle    0.078357
# Name: tratamento, dtype: float64

# %% [markdown]
# ### **Desafio 04**: Quantas tipos de drogas foram investigados.

# %%
qde_drogas = len(dados.query('tratamento == "com_droga"')['droga'].unique())
f"foram investigadas {qde_drogas:,} drogas."
# Out:
# 'foram investigadas 3,288 drogas.'

# %% [markdown]
# ### **Desafio 05**: Procurar na documentação o método query(pandas).
# Resp: link para a [documentação do método query](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.query.html)

# %% [markdown]
# ### **Desafio 06**: Renomear as colunas tirando o hífen.
# Observação: O erro que ocorreu na aula 1 não aconteceria se utilizassemos a
# consulta com o sinal de crase
# ```
# dados_filtrados = dados.query('`g-0` > 0')
# dados_filtrados.head()
# ```

# %%
# Observação: O erro que ocorreu na aula 1 não aconteceria se utilizassemos a
# consulta com o sinal de crase
dados_filtrados = dados.query('`g-0` > 0')
dados_filtrados.head()

# Para não termos que fazer a consulta com a crase, fazemos a substituição
# conforme orientação:
dados.columns = dados.columns.str.replace('-', '')
dados.columns
# Out:
# Index(['id', 'tratamento', 'tempo', 'dose', 'droga', 'g0', 'g1', 'g2', 'g3',
#        'g4',
#        ...
#        'c90', 'c91', 'c92', 'c93', 'c94', 'c95', 'c96', 'c97', 'c98', 'c99'],
#       dtype='object', length=877)

# %% [markdown]
# ### **Desafio 07**: Deixar os gráficos bonitões. (Matplotlib.pyplot) ( colocar título, label,...)

# %%
import matplotlib.pyplot as plt
col_serie = dados['tratamento'].value_counts()
lbls = list(dados['tratamento'].unique())
plt.pie(col_serie, autopct='%1.1f%%', shadow=True, explode=[0,0.1])
plt.legend(labels=lbls, loc = 'best')
plt.title('Tratamentos')
# Out:
# Text(0.5, 1.0, 'Tratamentos')

# %%
import matplotlib.pyplot as plt
col_serie = dados['tempo'].value_counts()
lbls = list(dados['tempo'].unique())
plt.pie(col_serie, autopct='%1.1f%%', shadow=Trueb)
plt.legend(labels=lbls, loc = 'best')
plt.title('Tempo')
# Out:
# Text(0.5, 1.0, 'Tempo')

# %%
#fazendo o bar plot com os index na ordem crescente de horas
x_label = [f'{x}h' for x in sorted(dados['tempo'].unique())]
plt.bar(x_label,dados['tempo'].value_counts(sort=True).sort_index(), 
        color=[(0, 0, 0.9, 0.2),(0, 0, 0.9, 0.3),(0, 0, 0.9, 0.4)], edgecolor= 'red')
plt.title('Contagem do Tempo de Análise')
plt.xlabel('Tempo de Análise')
plt.ylabel('Contagem')
# Out:
# Text(0, 0.5, 'Contagem')

# %% [markdown]
# ### **Desafio 08**: Resumo do que você aprendeu com os dados
# Em termos de ferramental para análise de dados, aprendemos:
# * A importar para o nosso caderno jupyter um arquivo tipo csv localizado em uma url conhecida na internet;
# * A obter uma visão das primeiras e últimas linhas do dataset importado;
# * Descobrir características do dataset: nº de linhas e de colunas, com o shape;
# * Descobrir caracteríscas dos dados armazenados em cada coluna.  Quais são eles e quantos de cada um deles existem, com o value_counts();
# * Aprendemos a renomear colunas.  Para tornar mais simples a sua chamada e evitar erros.
# * Aprendemos a fazer gráficos e a melhorar a sua apresentação, utilizando a biblioteca matplotlib;
#
# Em termos do dataset apresentado, tomei conhecimento de que:
# * A nossa base de dados é sobre teste de farmacos;
# * a coluna tratamento indica se estamos utilizando naquele registro uma droga ativa ou se se trata apenas de uma solução de controle;
# * A coluna tempo indica que o nosso experimento é feito em 24, 48 e 72 horas;
# * A coluna dose indica que a cultura é preparada em duas concentrações do farmaco (D1 e D2);
